# %%
import pandas as pd


noms_colonnes = ["sequence name", "frame number", "label", "HeightWidthRatio", "MajorMinorRatio", "BoundingBoxOccupancy", "MaxStdXZ", "HHmaxRatio", "H", "D", "P40"]  # Remplacez-les par les noms réels de vos colonnes

df = pd.read_csv(r'C:\Users\ludovic.souquet\Documents\GitHub\ludovic.souquet\Exercice_moustafa\URFD_Dataset.csv', names=noms_colonnes)
df.head(10)
# Out:
#   sequence name  frame number  label  HeightWidthRatio  MajorMinorRatio  \
# 0       fall-01             1     -1            3.1667           2.9098
# 1       fall-01             2     -1            3.3067           2.9699
# 2       fall-01             3     -1            3.1408           3.0506
# 3       fall-01             4     -1            3.4306           3.1435
# 4       fall-01             5     -1            3.6324           3.3012
# 5       fall-01             6     -1            3.3788           3.4746
# 6       fall-01             7     -1            3.3636           3.5179
# 7       fall-01             8     -1            3.1739           3.2962
# 8       fall-01             9     -1            3.4531           3.4923
# 9       fall-01            10     -1            3.6618           3.4449
#
#    BoundingBoxOccupancy  MaxStdXZ  HHmaxRatio          H          D       P40
# 0               0.55367  126.0258     1.03240  1899.5366  1055.9988  0.047310
# ...

# %% [markdown]
# ### Récupérez la première valeur de la colonne
# premiere_valeur = df[nom_colonne].iloc[0]
