# %% [markdown]
# ## Internet INTERDIT
# ## Memento Python autorisé
# ## Temps laissé au candidat : 2h
# ## Ne coder que dans les cellules indiquées.
# ## Ne pas rajouter ou supprimer des cellules
# ## Ne pas modifier les cellules de consigne.

# %% [markdown]
# # Exercice 00
# ## Validation des connaissances de base
#
# #### Ecicre un code python qui afiche 10 lignes de cette manière :
#
# Je suis la ligne 1
# Je suis la ligne 2
# Je suis la ligne 3
# Je suis la ligne 4
# Je suis la ligne 5
# Je suis la ligne 6
# Je suis la ligne 7
# Je suis la ligne 8
# Je suis la ligne 9
# Je suis la ligne 10
#
# Barème : 2/2

# %%
#Ne pas modifier cette cellule
note00 = 2

# %%
# Votre code ici : 
print("Je suis la ligne 1")
print("Je suis la ligne 2")
print("Je suis la ligne 3")
print("Je suis la ligne 4")
print("Je suis la ligne 5")
print("Je suis la ligne 6")
print("Je suis la ligne 7")
print("Je suis la ligne 8")
print("Je suis la ligne 9")
print("Je suis la ligne 10")
# Out:
# Je suis la ligne 1
# Je suis la ligne 2
# Je suis la ligne 3
# Je suis la ligne 4
# Je suis la ligne 5
# Je suis la ligne 6
# Je suis la ligne 7
# Je suis la ligne 8
# Je suis la ligne 9
# Je suis la ligne 10

# %% [markdown]
# #### Ecrire un code python qui demande à l'utilisateur son nom, son prénom, et son age et qui affiche la chaine de caractere paramétrique suivante :
#
# "Bonjour [prenom] [NOM], vous êtes majeur" ==> si l'utilisateur est majeur
# "Bonjour [prenom] [NOM], vous êtes mineur" ==> si l'utilisateur est mineur
#
# Par exemple, si l'utilisateur rentre
# Jérémy
# Ranguis
# 26
#
# Le programme écrira : "Bonjour Jérémy Ranguis, vous êtes majeur"
#
# #### Rajoutez à votre code une instruction qui permet d'écrire le nom tout le temps en majuscule.
#
# Le programme écrira alors : "Bonjour Jérémy RANGUIS, vous êtes majeur" même si initialement le nom vallait "Ranguis"
#
# Barème :
#
# Code de base : 2/2
# Nom en majuscules : 3/3

# %%
#Ne pas modifier cette cellule
note01 = 5

# %%
# Votre code ici : 
nom = input("Quel est votre nom ?")
prénom = input("Quel est votre prénom ?")
age = int(input("Quel est votre âge ?"))
if age<18:
    print("Bonjour", prénom, nom, "vous êtes mineur")
else:
    print("Bonjour", prénom, nom, "vous êtes majeur")
# Out:
# Quel est votre nom ?jeremy
# Quel est votre prénom ?ranguis
# Quel est votre âge ?27
# Bonjour ranguis jeremy vous êtes majeur

# %% [markdown]
# # Exercice 1 : affichage réseau
#
# ### Niveau 1 :
#
# Écrire un code python qui demande à l’utilisateur de saisir son nom, son prénom puis une adresse IPv4 en saisissant 4 nombres. On affiche ensuite un message indiquant le prénom et le nom du technicien suivi de l’adresse IP rentrée.
#
# Exemple :
#
# ![image.png](attachment:image.png)
#
# ### Niveau 2 :
#
# Rajouter à votre programme la gestion d'erreurs.
#
# - Pour chaque octet demandé, si l'utilisateur rentre un nombre en dehors de la plage autorisée (0-255), alors on le lui indique et on lui demande de saisir à nouveau la valeur de l'octet.
#
# Barème :
#
# -	Récupération des entrées standard : 2/2 pts
# -	Affichage de la sortie standard : 3/3 pts
# -   Gestion des types des entrées standard 2/2 pts
# -   Gestion des erreurs : 0/5

# %%
#Ne pas modifier cette cellule
note1 = 7

# %%
# Code de l'exercice 1
prénom = input("Saisir votre prénom ")
nom = input("Saisir votre nom ")
octet1 = int(input("Saisir le premier octet de l'adresse IP "))
octet2 = int(input("Saisir le second octet de l'adresse IP "))
octet3 = int(input("Saisir le troisième octet de l'adresse IP "))
octet4 = int(input("Saisir le quatrième octet de l'adresse IP "))
print("Bonjour", prénom, nom, "l'adresse IP rentrée est :", octet1, ".", octet2, ".", octet3, ".", octet4)
# Out:
# Saisir votre prénomLiam
# Saisir votre nomRAYNAL
# Saisir le premier octet de l'adresse IP 192
# Saisir le second octet de l'adresse IP 168
# Saisir le troisième octet de l'adresse IP 70
# Saisir le quatrième octet de l'adresse IP 55
# Bonjour Liam RAYNAL l'adresse IP rentrée est : 192 . 168 . 70 . 55

# %% [markdown]
# # Exercice 2 :
#
# Ecrire un code python qui demande à l'utilisateur de rentrer une phrase, et qui lui affiche si le nombre de lettres dans cette phrase est pair ou impair
#
# Par exmple, si on rentre "Bonjour, je suis un lapin" le programme écrira : "Le nombre de caractères dans votre phrase est impair"
#
# Barème :
#
# - Récupération de l'entrée standard : 2/2
# - Test conditionnel :
#    - structure : 3/3
#    - condition : 3/3
# - Affichage de la sortie : 2/2

# %%
#Ne pas modifier cette cellule
note2 = 10

# %%
# Code de l'exercice 2
s = input("Rentrez une phrase ")
compteur = 0
for caractere in s:
    compteur = compteur + 1
if compteur%2==0:
    print("Le nombre de caractères dans votre phrase est pair")
else:
    print("Le nombre de caractères dans votre phrase est impair")
# Out:
# Rentrez une phrase une
# Le nombre de caractères dans votre phrase est impair

# %% [markdown]
# # Exercice 3 :
#
# On récupère des chaines de caractères qui stockent le prénom et le nom d'un utilisateur. Par ex : "Jérémy RANGUIS".
# On souhaite faire un programme qui inverse les deux mots pour pouvoir afficher la chaine sous forme nom prénom.
#
# ### Niveau 1 :
#
# Ecrire un programme python qui inverse les deux mots donnés par l'utilisateur.
#
# ![Capture%20d%E2%80%99e%CC%81cran%202023-09-25%20a%CC%80%2017.25.56.png](attachment:Capture%20d%E2%80%99e%CC%81cran%202023-09-25%20a%CC%80%2017.25.56.png)
#
# Barème :
#
# - Méthode pour identifier les deux mots : /3
# - Constitution de la nouvelle chaine : /4
# - Affichage de la sortie : /2
#
# ### Niveau 2 :
#
# Complétez votre code pour qu'il produise une erreur si la chaine de départ contient plus de deux mots
#
# Barème :
#
# - Repérage de l'erreur : 4/4
# - Utilisation du try/except : 0/4

# %%
#Ne pas modifier cette cellule
note3 = 4

# %%
# Code de l'exercice 3
s = input("Entrez votre prénom nom ")
compteur = 0
for caractere in s:
    if caractere==' ':
        compteur = compteur +1
    if compteur>1:
        Erreur
compteur1 = 0
for caractere in s:
    if caractere==' ':
        break
    compteur1 = compteur1 + 1
mot1= s[0:compteur1]
mot2= s[compteur1:]
print(mot2, mot1)
# Out:
# Entrez votre prénom nom jeremy ranguis
#  ranguis jeremy

# %% [markdown]
# # Exercice 4 :
#
# On dispose d'une liste initiale de produits et de plusieurs listes de catégories de produits.
#
# liste_initiale = ["pomme", "tablette", "téléphone", "poire", "table"]
# fruits = ["pomme", "poire", "abricot", "cerise"]
# numerique = ["tablette", "téléphone", "PC", "Ipad"]
# mobilier = ["table", "armoire"]
#
# Ecrire un programme qui indique combien d'éléments il y d'éléments de chaque catégorie dans la liste de départ.
#
# Par exemple, avec la liste initiale donnée le programme écrit :
#
# Il y a 2 fruits dans la liste
# Il y a 2 éléments numériques dans la liste
# Il y a 1 élement mobilier dans la liste
#
# Barème :
#
# - Structure algorithmique adoptée : 6/6
# - Calcul du nombre d'éléments par catégories : 4/4
# - Affichage de la sortie comme demandé : 4/4

# %%
#Ne pas modifier cette cellule
note4 = 14

# %%
# Code de l'exercice 4
liste_initiale = ["pomme", "tablette", "téléphone", "poire", "table"]
fruits = ["pomme", "poire", "abricot", "cerise"]
numerique = ["tablette", "téléphone", "PC", "Ipad"]
mobilier = ["table", "armoire"]
compteur = 0
for x in liste_initiale:
    for y in fruits:
        if (x==y):
            compteur = compteur +1
print("Il y a", compteur, "fruits dans la liste")
compteur = 0
for x in liste_initiale:
    for z in numerique:
        if (x==z):
            compteur = compteur +1
print("Il y a", compteur, "élements numeriques dans la liste")
compteur = 0
for x in liste_initiale:
    for a in mobilier:
        if (x==a):
            compteur = compteur +1
print("Il y a", compteur, "élement mobilier dans la liste")
compteur = 0
# Out:
# Il y a 2 fruits dans la liste
# Il y a 2 élements numeriques dans la liste
# Il y a 1 élement mobilier dans la liste

# %% [markdown]
# # Exercice 5 : Compte des Occurrences de Mots
#
# Écrivez un code python qui donne un dictionnaire contenant le compte des occurrences de chaque mot dans une chaine de caractère donnée.
# Les mots sont définis comme des séquences de caractères séparées par des espaces.
# Ignorez la casse (majuscule/minuscule) des mots.
#
#
# Exemple :
#
# Entrée : "Le chat est sur le toit. Le chat est mignon."
# Sortie : {'le': 2, 'chat': 2, 'est': 2, 'sur': 1, 'toit.': 1, 'mignon.': 1}
#
#
# Contraintes :
#
# La sortie doit être un dictionnaire.
# Ignorez la casse (considérez les mots en minuscules).
# Ignorez la ponctuation (.,!?) attachée aux mots.
#
# Barème :
#
# - Structure algorithmique : /4
# - Maitrise des techniques du dictionnaire : /5
# - Maitrise de la casse : /3

# %%
#Ne pas modifier cette cellule
note5 = 0

# %%
# Code de l'exercice 5

# %% [markdown]
# # Résultats :

# %%
ponderations = [2, 2, 3, 2, 4, 1]
totaux = [7, 12, 10, 17, 14, 12]
notes = [note00+note01, note1, note2, note3, note4, note5]

#print(notes, sum(notes), ponderations)
note_ponderee_somme = 0 

for note, ponderation, total in zip(notes, ponderations, totaux):
    #print("je vais multiplier la note : ", note, "par le coeff", ponderation)
    note_ponderee_somme+= ponderation*(note*20)/total

#print("note ponderee somme : ", note_ponderee_somme, "somme coeff : ", sum(ponderations))
note_ponderee20 = round(note_ponderee_somme/sum(ponderations),1)

print("Votre note est : ", note_ponderee20, "/20")
# Out:
# Votre note est :  15.2 /20
