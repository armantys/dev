# %%
# import os
# import nbformat
# from pprint import pprint

# # Dictionnaire pour stocker les valeurs des variables trouvées
# valeurs_variables = {}
# resultats = {}




# def listdirectory(path,n): 
#     fichiers_ipynb = [fichier for fichier in os.listdir(path) if fichier.endswith('.ipynb')]
#     for noms in fichiers_ipynb:
#         nom = noms.split(".")[0]
#         if fichiers_ipynb != "script.ipynb":
#             with open(path + noms, 'r',encoding='utf-8') as fichier:
#                 contenu = nbformat.read(fichier,as_version=4)
#                 for cellule in contenu['cells'][:-2]:
#                     if cellule['cell_type'] == 'code':
#                         # Extraire le contenu du code dans la cellule
#                         code = cellule['source']
#                         for liste in n:
#                             if liste in code:
#                                 exec(code)  # Exécute le code de la cellule
#                                 valeurs_variables[liste] = locals()[liste]
                               
#                 if nom not in resultats:
#                     resultats[nom] = {}
    
#                 for exercice, note in valeurs_variables.items():
#                     resultats[nom][exercice] = note
#     print(resultats)

    
    
            
# # Nom de la variable à rechercher
# note = ["note00", "note01", "note1", "note2", "note3", "note4", "note5"]          
# chemin = r"C:\Users\ludovic.souquet\Documents\GitHub\ludovic.souquet\piscine_python\Evaluation python classroom ciel 28092923\Evaluation python classroom ciel 28092923\\"

# listdirectory(chemin, note)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[2], line 42
#      39 note = ["note00", "note01", "note1", "note2", "note3", "note4", "note5"]
#      40 chemin = r"C:\Users\ludovic.souquet\Documents\GitHub\ludovic.souquet\piscine_python\Evaluation python classroom ciel 28092923\Evaluation python classroom ciel 28092923\\"
# ---> 42 listdirectory(chemin, note)
#
# Cell In[2], line 25, in listdirectory(path, n)
#      23         for liste in n:
#      24             if liste in code:
# ---> 25                 exec(code)  # Exécute le code de la cellule
#      26                 valeurs_variables[liste] = locals()[liste]
#      28 if nom not in resultats:
#
# File <string>:42
#
# File <string>:25, in listdirectory(path, n)
#
# File <string>:42
#
# File <string>:25, in listdirectory(path, n)
#
#     [... skipping similar frames: <module> at line 42 (1475 times), listdirectory at line 25 (1474 times)]
#
# File <string>:25, in listdirectory(path, n)
#
# File <string>:42
#
# File <string>:18, in listdirectory(path, n)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\__init__.py:171, in read(fp, as_version, capture_validation_error, **kwargs)
#     168     with open(fp, encoding="utf-8") as f:
#     169         return reads(f.read(), as_version, capture_validation_error, **kwargs)
# --> 171 return reads(buf, as_version, capture_validation_error, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\__init__.py:89, in reads(s, as_version, capture_validation_error, **kwargs)
#      63 def reads(s, as_version, capture_validation_error=None, **kwargs):
#      64     """Read a notebook from a string and return the NotebookNode object as the given version.
#      65
#      66     The string can contain a notebook of any version.
#    (...)
#      87         The notebook that was read.
#      88     """
# ---> 89     nb = reader.reads(s, **kwargs)
#      90     if as_version is not NO_CONVERT:
#      91         nb = convert(nb, as_version)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\reader.py:80, in reads(s, **kwargs)
#      78 if major in versions:
#      79     try:
# ---> 80         return versions[major].to_notebook_json(nb_dict, minor=minor)
#      81     except AttributeError as e:
#      82         msg = f"The notebook is invalid and is missing an expected key: {e}"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\v4\nbjson.py:38, in JSONReader.to_notebook(self, d, **kwargs)
#      33 def to_notebook(self, d, **kwargs):
#      34     """Convert a disk-format notebook dict to in-memory NotebookNode
#      35
#      36     handles multi-line values as strings, scrubbing of transient values, etc.
#      37     """
# ---> 38     nb = from_dict(d)
#      39     nb = rejoin_lines(nb)
#      40     nb = strip_transient(nb)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in from_dict(d)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in <dictcomp>(.0)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in from_dict(d)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in <listcomp>(.0)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in from_dict(d)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in <dictcomp>(.0)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in from_dict(d)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in <listcomp>(.0)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in from_dict(d)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:47, in <dictcomp>(.0)
#      40 """Convert dict to dict-like NotebookNode
#      41
#      42 Recursively converts any dict in the container to a NotebookNode.
#      43 This does not check that the contents of the dictionary make a valid
#      44 notebook or part of a notebook.
#      45 """
#      46 if isinstance(d, dict):
# ---> 47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in from_dict(d)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:49, in <listcomp>(.0)
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
#      48 elif isinstance(d, (tuple, list)):
# ---> 49     return [from_dict(i) for i in d]
#      50 else:
#      51     return d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nbformat\notebooknode.py:48, in from_dict(d)
#      46 if isinstance(d, dict):
#      47     return NotebookNode({k: from_dict(v) for k, v in d.items()})
# ---> 48 elif isinstance(d, (tuple, list)):
#      49     return [from_dict(i) for i in d]
#      50 else:
#
# RecursionError: maximum recursion depth exceeded in __instancecheck__

# %%
import os
import nbformat
from pprint import pprint
# Dictionnaire pour stocker les résultats
valeurs_variables = {}
resultats = {}

def listdirectory(path, variables_a_chercher):
    # Liste des fichiers avec l'extension .ipynb dans le répertoire
    fichiers_ipynb = [fichier for fichier in os.listdir(path) if fichier.endswith('.ipynb')]

    for nom_fichier in fichiers_ipynb:
        nom = nom_fichier.split(".")[0]

        # Vérifier si le fichier n'est pas "script.ipynb"
        if nom_fichier != "script.ipynb":
            with open(os.path.join(path, nom_fichier), 'r', encoding='utf-8') as fichier:
                contenu = nbformat.read(fichier, as_version=4)

                for cellule in contenu['cells'][:-2]:
                    if cellule['cell_type'] == 'code':
                        # Extraire le contenu du code dans la cellule
                        code = cellule['source']

                        for variable in variables_a_chercher:
                            if variable in code:
                                exec(code)  # Exécute le code de la cellule
                                valeurs_variables[variable] = locals()[variable]

                # Créer le dictionnaire si l'élève n'existe pas
                if nom not in resultats:
                    resultats[nom] = {}

                # Ajouter les notes à l'élève et à l'exercice spécifiés
                for exercice, note in valeurs_variables.items():
                    resultats[nom][exercice] = note

    # Afficher le dictionnaire résultant
    pprint(resultats)

# Noms des variables à rechercher
notes = ["note00", "note01", "note1", "note2", "note3", "note4", "note5"]

# Chemin vers le répertoire contenant les fichiers .ipynb
chemin = r"C:\Users\ludovic.souquet\Documents\GitHub\ludovic.souquet\piscine_python\Evaluation python classroom ciel 28092923\Evaluation python classroom ciel 28092923\\"

listdirectory(chemin, notes)
# Out:
# {'Alois alois': {'note00': 2,
#                  'note01': 5,
#                  'note1': 12,
#                  'note2': 10,
#                  'note3': 0,
#                  'note4': 0,
#                  'note5': 0},
#  'CHUPANOV Muslim': {'note00': 2,
#                      'note01': 5,
#                      'note1': 10,
#                      'note2': 10,
#                      'note3': 4,
#                      'note4': 6,
#                      'note5': 3},
#  'Corentin VIDONNE': {'note00': 2,
#                       'note01': 5,
#                       'note1': 12,
#                       'note2': 10,
#                       'note3': 11,
#                       'note4': 14,
#                       'note5': 12},
#  'FELIX noah': {'note00': 2,
#                 'note01': 2,
#                 'note1': 10,
#                 'note2': 5,
#                 'note3': 7,
#                 'note4': 0,
#                 'note5': 4},
#  'FORET Mathis': {'note00': 1,
#                   'note01': 5,
#                   'note1': 7,
#                   'note2': 10,
#                   'note3': 9,
#                   'note4': 0,
#                   'note5': 0},
#  'Gayanal gaudebiere': {'note00': 2,
#                         'note01': 5,
#                         'note1': 7,
#                         'note2': 10,
#                         'note3': 4,
#                         'note4': 14,
#                         'note5': 0},
#  'Killian BEHAVA': {'note00': 2,
#                     'note01': 5,
#                     'note1': 12,
#                     'note2': 10,
#                     'note3': 9,
#                     'note4': 14,
#                     'note5': 12},
#  'MENICUCCI Kenni': {'note00': 2,
#                      'note01': 5,
#                      'note1': 10,
#                      'note2': 0,
#                      'note3': 0,
#                      'note4': 3,
#                      'note5': 0},
#  'Malwan Mouttake': {'note00': 2,
#                      'note01': 5,
#                      'note1': 12,
#                      'note2': 10,
#                      'note3': 0,
#                      'note4': 14,
#                      'note5': 0},
#  'Mathys guinet': {'note00': 2,
#                    'note01': 5,
#                    'note1': 9,
#                    'note2': 10,
#                    'note3': 8,
#                    'note4': 14,
#                    'note5': 12},
#  'Maxime Michaud': {'note00': 2,
#                     'note01': 5,
#                     'note1': 11,
#                     'note2': 10,
#                     'note3': 6,
#                     'note4': 6,
#                     'note5': 0},
#  'Michaud Loi╠êc': {'note00': 2,
#                     'note01': 5,
#                     'note1': 5,
#                     'note2': 6,
#                     'note3': 0,
#                     'note4': 0,
#                     'note5': 0},
#  "Mous'ab Chebira": {'note00': 2,
#                      'note01': 5,
#                      'note1': 11,
#                      'note2': 10,
#                      'note3': 0,
#                      'note4': 12,
#                      'note5': 0},
#  'Ouicher Hilies': {'note00': 0,
#                     'note01': 1,
#                     'note1': 2,
#                     'note2': 0,
#                     'note3': 0,
#                     'note4': 3,
#                     'note5': 0},
#  'Raphael Tep': {'note00': 2,
#                  'note01': 5,
#                  'note1': 12,
#                  'note2': 8,
#                  'note3': 7,
#                  'note4': 14,
#                  'note5': 4},
#  'Uslu Semih': {'note00': 1,
#                 'note01': 1,
#                 'note1': 4,
#                 'note2': 0,
#                 'note3': 2,
#                 'note4': 4,
#                 'note5': 0},
#  'Vincent JACQUET': {'note00': 2,
#                      'note01': 5,
#                      'note1': 5,
#                      'note2': 0,
#                      'note3': 13,
#                      'note4': 12,
#                      'note5': 0},
#  'Yanis benyahia': {'note00': 2,
#                     'note01': 2,
#                     'note1': 9,
#                     'note2': 10,
#                     'note3': 0,
#                     'note4': 14,
#                     'note5': 0},
#  'anas anas': {'note00': 2,
#                'note01': 5,
#                'note1': 10,
#                'note2': 10,
#                'note3': 3,
#                'note4': 14,
#                'note5': 0},
#  'chamsdine chamsdine': {'note00': 2,
#                          'note01': 5,
#                          'note1': 0,
#                          'note2': 0,
#                          'note3': 0,
#                          'note4': 0,
#                          'note5': 0},
#  'juru-nzanana exauce': {'note00': 2,
#                          'note01': 5,
#                          'note1': 8,
#                          'note2': 10,
#                          'note3': 2,
#                          'note4': 0,
#                          'note5': 0},
#  'leo macotta': {'note00': 0,
#                  'note01': 1,
#                  'note1': 3,
#                  'note2': 0,
#                  'note3': 0,
#                  'note4': 0,
#                  'note5': 0},
#  'matheo ribeiro': {'note00': 2,
#                     'note01': 2,
#                     'note1': 7,
#                     'note2': 10,
#                     'note3': 9,
#                     'note4': 14,
#                     'note5': 0}}

# %%
import os
import nbformat
from pprint import pprint


totaux = [7, 12, 10, 17, 14, 12]
ponderations = [2, 2, 4, 2, 4, 1]

def moyenne():
    somme_moyenne_par_eleve = 0
    for eleve, valeur in resultats.items():
        exo = []
        note_ponderee_somme = 0 
        for exercice,note in valeur.items():
            exer = [*exercice.replace("note", "")]
            if len(exer)>1:
                try:
                    exo[int(exer[0])] += note
                except:
                    exo.append(note)
            else:
                exo.append(note)

            
        for note, ponderation, total in zip(exo, ponderations, totaux):
            note_ponderee_somme += ponderation * (note * 20) / total
            # Initialisation de la somme pondérée des notes
        moyenne_par_eleve = note_ponderee_somme / sum(ponderations)
        somme_moyenne_par_eleve += moyenne_par_eleve
    moyenne_de_classe = somme_moyenne_par_eleve / len(resultats)
    print("la moyenne general est : ",round(moyenne_de_classe,2))
        
        
moyenne()
# Out:
# la moyenne general est :  11.44

# %%
import os
import nbformat
from pprint import pprint

def moyenne_par_exercice():
    # Initialiser un dictionnaire pour stocker les notes par exercice
    notes_par_exercice = {}

    # Parcourir chaque élève
    for eleve, valeur in resultats.items():
        # Parcourir chaque exercice pour cet élève
        for exercice, note in valeur.items():
            # Remplacer "note" par "exercice" dans le nom de l'exercice
            exer = exercice.replace("note", "exercice")

            # Ajouter la note à la liste correspondante dans le dictionnaire
            if exer not in notes_par_exercice:
                notes_par_exercice[exer] = []    
            notes_par_exercice[exer].append(note)
    
    # Calculer la moyenne pour chaque exercice
    moyenne_par_exercice = {exer: sum(notes) / len(notes) for exer, notes in notes_par_exercice.items()}
    pprint(moyenne_par_exercice)
    # Afficher la moyenne par exercice
    for exer, moyenne in moyenne_par_exercice.items():
        print(f"la moyenne de l'{exer} est : {round(moyenne,2)}")

# Appel de la fonction
moyenne_par_exercice()
# Out:
# {'exercice00': 1.7391304347826086,
#  'exercice01': 4.086956521739131,
#  'exercice1': 8.173913043478262,
#  'exercice2': 6.913043478260869,
#  'exercice3': 4.086956521739131,
#  'exercice4': 7.478260869565218,
#  'exercice5': 2.0434782608695654}
# la moyenne de l'exercice00 est : 1.74
# la moyenne de l'exercice01 est : 4.09
# la moyenne de l'exercice1 est : 8.17
# la moyenne de l'exercice2 est : 6.91
# la moyenne de l'exercice3 est : 4.09
# la moyenne de l'exercice4 est : 7.48
# la moyenne de l'exercice5 est : 2.04
